# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('c:\\Users\\user\\Downloads\\Used_Bikes.csv')
df.head()
# Out:
#                               bike_name   price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1           Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                  Triumph Daytona 675R  600000      Delhi         110
# 3                  TVS Apache RTR 180cc   65000  Bangalore       16329
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
#
#          owner  age  power          brand
# 0  First Owner    3    110            TVS
# 1  First Owner    4    350  Royal Enfield
# 2  First Owner    8    675        Triumph
# 3  First Owner    4    180            TVS
# 4  First Owner    3    150         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  int64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  int64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  int64
#  6   power       32648 non-null  int64
#  7   brand       32648 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   object
#  1   price       7324 non-null   int64
#  2   city        7324 non-null   object
#  3   kms_driven  7324 non-null   int64
#  4   owner       7324 non-null   object
#  5   age         7324 non-null   int64
#  6   power       7324 non-null   int64
#  7   brand       7324 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 515.0+ KB

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df['brand'].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW', 'Jawa', 'Indian', 'MV',
#        'Rajdoot', 'LML', 'Yezdi', 'Ideal'],
#       dtype='object', name='brand')

# %%
brand_list=['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
       'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
       'Benelli', 'Triumph', 'Ducati', 'BMW']
brand_list
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df=df[df["brand"].isin(brand_list)]
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
categorial=df.select_dtypes(include="O")    # catgorical data types 
categorial
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...

# %%
numerical=df.select_dtypes(exclude="O")    # numerical data types
numerical
# Out:
#        price  kms_driven  age  power
# 0      35000       17654    3    110
# 1     119900       11000    4    350
# 2     600000         110    8    675
# 3      65000       16329    4    180
# 4      80000       10000    3    150
# ...      ...         ...  ...    ...
# 9362   25000       48587    8    150
# 9369   35000       60000    9    220
# 9370  450000        3430    4    750
# 9371  139000       21300    4    400
# 9372   80000        7127    5    220
#
# [7307 rows x 4 columns]

# %%
categorial['owner'].value_counts()
# Out:
# owner
# First Owner             6628
# Second Owner             586
# Third Owner               83
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
categorial['brand']
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7307, dtype: object

# %%
dt1={"First Owner":1,"Second Owner":2,"Third Owner":3,"Fourth Owner Or More":4}
categorial['owner']= categorial['owner'].map(dt1)

# %%
categorial
# Out:
#                                  bike_name       city  owner            brand
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad      1              TVS
# 1              Royal Enfield Classic 350cc      Delhi      1    Royal Enfield
# 2                     Triumph Daytona 675R      Delhi      1          Triumph
# 3                     TVS Apache RTR 180cc  Bangalore      1              TVS
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore      1           Yamaha
# ...                                    ...        ...    ...              ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi      1             Hero
# 9369                   Bajaj Avenger 220cc  Bangalore      1            Bajaj
# 9370        Harley-Davidson Street 750 ABS    Jodhpur      1  Harley-Davidson
# 9371                 Bajaj Dominar 400 ABS  Hyderabad      1            Bajaj
# 9372              Bajaj Avenger Street 220  Hyderabad      1            Bajaj
#
# [7307 rows x 4 columns]

# %%
categorial["brand"].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW'],
#       dtype='object', name='brand')

# %%
brand_list
dt={}
for i in range(0,len(brand_list)):
    dt[brand_list[i]]=i

# %%
dt
# Out:
# {'Bajaj': 0,
#  'Royal Enfield': 1,
#  'Hero': 2,
#  'Honda': 3,
#  'Yamaha': 4,
#  'TVS': 5,
#  'KTM': 6,
#  'Suzuki': 7,
#  'Harley-Davidson': 8,
#  'Kawasaki': 9,
#  'Hyosung': 10,
#  'Mahindra': 11,
#  'Benelli': 12,
#  'Triumph': 13,
#  'Ducati': 14,
#  'BMW': 15}

# %%
categorial['brand'] = categorial['brand'].map(dt)
categorial
# Out:
#                                  bike_name       city  owner  brand
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad      1      5
# 1              Royal Enfield Classic 350cc      Delhi      1      1
# 2                     Triumph Daytona 675R      Delhi      1     13
# 3                     TVS Apache RTR 180cc  Bangalore      1      5
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore      1      4
# ...                                    ...        ...    ...    ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi      1      2
# 9369                   Bajaj Avenger 220cc  Bangalore      1      0
# 9370        Harley-Davidson Street 750 ABS    Jodhpur      1      8
# 9371                 Bajaj Dominar 400 ABS  Hyderabad      1      0
# 9372              Bajaj Avenger Street 220  Hyderabad      1      0
#
# [7307 rows x 4 columns]

# %%
categorial['Owner_name']="sanjana"
categorial
# Out:
#                                  bike_name       city  owner  brand Owner_name
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad      1      5    sanjana
# 1              Royal Enfield Classic 350cc      Delhi      1      1    sanjana
# 2                     Triumph Daytona 675R      Delhi      1     13    sanjana
# 3                     TVS Apache RTR 180cc  Bangalore      1      5    sanjana
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore      1      4    sanjana
# ...                                    ...        ...    ...    ...        ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi      1      2    sanjana
# 9369                   Bajaj Avenger 220cc  Bangalore      1      0    sanjana
# 9370        Harley-Davidson Street 750 ABS    Jodhpur      1      8    sanjana
# 9371                 Bajaj Dominar 400 ABS  Hyderabad      1      0    sanjana
# 9372              Bajaj Avenger Street 220  Hyderabad      1      0    sanjana
#
# [7307 rows x 5 columns]

# %%
categorial.drop(['bike_name','city','Owner_name'],axis=1,inplace=True)
categorial
# Out:
#       owner  brand
# 0         1      5
# 1         1      1
# 2         1     13
# 3         1      5
# 4         1      4
# ...     ...    ...
# 9362      1      2
# 9369      1      0
# 9370      1      8
# 9371      1      0
# 9372      1      0
#
# [7307 rows x 2 columns]

# %%
data=pd.concat([categorial,numerical],axis=1)
data
# Out:
#       owner  brand   price  kms_driven  age  power
# 0         1      5   35000       17654    3    110
# 1         1      1  119900       11000    4    350
# 2         1     13  600000         110    8    675
# 3         1      5   65000       16329    4    180
# 4         1      4   80000       10000    3    150
# ...     ...    ...     ...         ...  ...    ...
# 9362      1      2   25000       48587    8    150
# 9369      1      0   35000       60000    9    220
# 9370      1      8  450000        3430    4    750
# 9371      1      0  139000       21300    4    400
# 9372      1      0   80000        7127    5    220
#
# [7307 rows x 6 columns]

# %%
x = data.drop('price' , axis= 1)

# %%
y = data[['price']]

# %%
x
# Out:
#       owner  brand  kms_driven  age  power
# 0         1      5       17654    3    110
# 1         1      1       11000    4    350
# 2         1     13         110    8    675
# 3         1      5       16329    4    180
# 4         1      4       10000    3    150
# ...     ...    ...         ...  ...    ...
# 9362      1      2       48587    8    150
# 9369      1      0       60000    9    220
# 9370      1      8        3430    4    750
# 9371      1      0       21300    4    400
# 9372      1      0        7127    5    220
#
# [7307 rows x 5 columns]

# %%
y
# Out:
#        price
# 0      35000
# 1     119900
# 2     600000
# 3      65000
# 4      80000
# ...      ...
# 9362   25000
# 9369   35000
# 9370  450000
# 9371  139000
# 9372   80000
#
# [7307 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# x and y --> training and tasting split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)   #test size -> 20 % and other reamaining part - trainning size = 80%
#prediction -> by head   for example when we pass x as arugement get by head y by machine learning algo# x, y for testing and for trainnig only y head(actual value)
# x, y for testing and for trainnig only y head(actual value)

# %%
y_train
# Out:
#        price
# 1486   28000
# 5769   46800
# 2     600000
# 3807   70000
# 3888   40000
# ...      ...
# 8763   90000
# 1357  105000
# 4571   12000
# 7489  109999
# 7722   95000
#
# [5845 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lg = LinearRegression()

# %%
x_train.isnull().sum()
# Out:
# owner         0
# brand         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %%
# Algorithym training
lg.fit(x_train , y_train)    # training data for training purpose
# Out:
# LinearRegression()

# %%
# model Testing step -> model evaluation step:
# after complete training of model we start evalautions of our model for check it's performance and efficency
# model evaluation depends on different technique algo
    # Regression model

# %%
# Training and Testing
print("Training score is:" , round(lg.score(x_train , y_train)*100 ,2))
print("Testing score is:" , round(lg.score(x_test, y_test)*100 ,2))

## you need grater then 90%
# accuracy > 90%
# Out:
# Training score is: 73.9
# Testing score is: 74.25

# %%
y_hat = lg.predict(x_test)

# %%
x_test.shape
# Out:
# (1462, 5)

# %%
y_test["preduction"] = y_hat
y_test
# Out:
#        price     preduction
# 4277   40000   15142.672916
# 6509   19000    1150.676991
# 8298   86900   65332.580866
# 3727   10000  -14280.790661
# 4920    9400   23010.279732
# ...      ...            ...
# 8645  250000  232300.273812
# 3085   12000  -10540.212866
# 1690   48000   88155.794819
# 7486   12500  -23285.974058
# 8691  120000  239530.005620
#
# [1462 rows x 2 columns]

# %%
y_tester = y_test['preduction'].map(lambda x: round(x,2))
y_tester
# Out:
# 4277     15142.67
# 6509      1150.68
# 8298     65332.58
# 3727    -14280.79
# 4920     23010.28
#           ...
# 8645    232300.27
# 3085    -10540.21
# 1690     88155.79
# 7486    -23285.97
# 8691    239530.01
# Name: preduction, Length: 1462, dtype: float64

# %%
y_tester.head()
# Out:
# 4277    15142.67
# 6509     1150.68
# 8298    65332.58
# 3727   -14280.79
# 4920    23010.28
# Name: preduction, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
rdf = RandomForestRegressor()

# %%
rdf.fit(x_train , y_train)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
print("Training score is:" , round(rdf.score(x_train , y_train)*100 ,2))
print("Testing score is:" , round(rdf.score(x_test, y_test['price'])*100 ,2))
# Out:
# Training score is: 98.34
# Testing score is: 93.09

# %%
ls = ["yasmeen" , "yashu" , "yashi" , "jashu"] 
ls
# Out:
# ['yasmeen', 'yashu', 'yashi', 'jashu']

# %%
import joblib

# %%
joblib.dump(ls, 'favourate_student.lb')
# Out:
# ['favourate_student.lb']

# %%
favourate_Student = joblib.load('favourate_student.lb')
favourate_Student
# Out:
# ['yasmeen', 'yashu', 'yashi', 'jashu']

# %%
joblib.dump(lg , 'LinearRegression_model.lb')
# Out:
# ['LinearRegression_model.lb']
